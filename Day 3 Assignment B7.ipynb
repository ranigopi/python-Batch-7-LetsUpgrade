# %%
print("Assignment No 1:")
a=int(input("enter the altitude: "))
if a>5000:
    print("go around and try later")
elif a>1000 and a<=5000:
    print("come down to 1000")
else :
    print("land the plane")
# Out:
# Assignment No 1:
# enter the altitude: 500
# land the plane

# %%
 
print ("Assignment No 2: ")
for num in range(1,200):
   if num > 1:
       for i in range(2, num):
           if (num % i) == 0:
               break
       else:
           print("prime numbers is",num)
# Out:
# Assignment No 2:
# prime numbers is 2
# prime numbers is 3
# prime numbers is 5
# prime numbers is 7
# prime numbers is 11
# prime numbers is 13
# prime numbers is 17
# prime numbers is 19
# prime numbers is 23
# prime numbers is 29
# prime numbers is 31
# prime numbers is 37
# prime numbers is 41
# prime numbers is 43
# prime numbers is 47
# prime numbers is 53
# prime numbers is 59
# prime numbers is 61
# prime numbers is 67
# prime numbers is 71
# prime numbers is 73
# prime numbers is 79
# prime numbers is 83
# prime numbers is 89
# prime numbers is 97
# prime numbers is 101
# prime numbers is 103
# prime numbers is 107
# prime numbers is 109
# prime numbers is 113
# prime numbers is 127
# prime numbers is 131
# prime numbers is 137
# prime numbers is 139
# prime numbers is 149
# prime numbers is 151
# prime numbers is 157
# prime numbers is 163
# prime numbers is 167
# prime numbers is 173
# prime numbers is 179
# prime numbers is 181
# prime numbers is 191
# prime numbers is 193
# prime numbers is 197
# prime numbers is 199
